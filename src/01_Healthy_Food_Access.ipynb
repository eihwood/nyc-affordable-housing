# %%
import pandas as pd

# %%
store_locs = pd.read_csv("../data/Retail_Food_Stores.csv")

store_locs = store_locs.loc[store_locs['County'].isin(['Queens', 'Kings', 'Bronx', 'New York', 'Richmond'])]

# %%
# subset to get only groceries
# Out:
#          County  License Number Operation Type Establishment Type  \
# 1        Queens          756125          Store                JAC
# 3      Richmond          756121          Store                JAC
# 4        Queens          756120          Store                JAC
# 5        Queens          756118          Store                JAC
# 8      New York          756114          Store                JAC
# ...         ...             ...            ...                ...
# 21993     Bronx          600103          Store                JAC
# 21994     Bronx          600057          Store             JABCHK
# 21995     Bronx          600049          Store                JAC
# 21996     Bronx          600005          Store             JABCHK
# 23050    Queens          475040          Store               JADX
#
#                              Entity Name                 DBA Name  \
# 1                           7-ELEVEN INC   7-ELEVEN STORE #35026H
# ...

# %%
# read in the healthy food flags
data = pd.read_csv("../data/Recognized_Shop_Healthy_Stores.csv")
data
# Out:
#                       Store Name  Street Address         Address   Borough  \
# 0                 SIRAH 1720 LLC   535 MARCY AVE             NaN  Brooklyn
# 1         FIRST STOP GROCERY INC   643 MARCY AVE             NaN  Brooklyn
# 2               AANDE DIRECT LLC    40 LEWIS AVE             NaN  Brooklyn
# 3                CENTRAL ORGANIC  67 CENTRAL AVE             NaN  Brooklyn
# 4           194 THROOP FOOD CORP    777 PARK AVE             NaN  Brooklyn
# ..                           ...             ...             ...       ...
# 363          El Barrio Superette            1858   Lexington Ave  New York
# 364  New King Deli Grocery Corp.              23  East 115th St.  New York
# 365   Little Mexico Meat Grocery            2119       Third Ave  New York
# 366        Paniagua Deli Grocery             203  East 115th St.  New York
# 367               JJ Food Market             153   East 99th St.  New York
#
# ...

# %%
# check to see if the names are the same in the two databases
all_store_name_set = set(store_locs['DBA Name'])
healthy_awards = set(data['Store Name'])

healthy_awards&all_store_name_set
# Out:
# {'2001 GOURMET DELI',
#  'AMIGOS GROCERY',
#  'BANESA DELI GROCERY 2',
#  'BODEGA BUILT',
#  'C-TOWN',
#  'CONCOURSE FOOD PLAZA',
#  'FELINO GROCERY',
#  'FELOMAR GROCERY STORE',
#  'FINE FARE SUPERMARKET',
#  'JJN CORP',
#  'LOS PRIMOS GROCERY'}
